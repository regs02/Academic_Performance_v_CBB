# %% [markdown]
# # Reagan's Notebook

# %% [markdown]
# maybe do random forest
# change the bucket size to around 10.
#
# maybe do team by team basis, will team a beat team b
# for random forest theres classification and regression

# %%
#imports
import pandas as pd

# %%
df_education = pd.read_csv('database.csv')
df_education.head()
# Out:
#    SCHOOL_ID             SCHOOL_NAME  SCHOOL_TYPE  ACADEMIC_YEAR  SPORT_CODE  \
# 0     100654  Alabama A&M University            0           2014           1
# 1     100654  Alabama A&M University            0           2014           4
# 2     100654  Alabama A&M University            0           2014           2
# 3     100654  Alabama A&M University            0           2014           6
# 4     100654  Alabama A&M University            0           2014          13
#
#          SPORT_NAME  NCAA_DIVISION  NCAA_SUBDIVISION  \
# 0          Baseball              1                 2
# 1          Football              1                 2
# 2  Men's Basketball              1                 2
# 3        Men's Golf              1                 2
# 4      Men's Tennis              1                 2
#
#                     NCAA_CONFERENCE  FOURYEAR_ATHLETES  ...  2006_ELIGIBILITY  \
# 0  Southwestern Athletic Conference                 80  ...            0.8974
# ...

# %%
#tjis gets only men's bball data from education dataset
df_education_mens = df_education[df_education["SPORT_NAME"] == "Men's Basketball"]
df_education_div = df_education_mens[df_education_mens["NCAA_DIVISION"] == 1]

df_education_div.to_csv('mens_bball_education.csv', index=False)

#rename columns so easier to merge
df_education_div.head()
# Out:
#     SCHOOL_ID                          SCHOOL_NAME  SCHOOL_TYPE  \
# 2      100654               Alabama A&M University            0
# 17     100663  University of Alabama at Birmingham            0
# 33     100724             Alabama State University            0
# 51     100751                University of Alabama            0
# 72     100858                    Auburn University            0
#
#     ACADEMIC_YEAR  SPORT_CODE        SPORT_NAME  NCAA_DIVISION  \
# 2            2014           2  Men's Basketball              1
# 17           2014           2  Men's Basketball              1
# 33           2014           2  Men's Basketball              1
# 51           2014           2  Men's Basketball              1
# 72           2014           2  Men's Basketball              1
#
#     NCAA_SUBDIVISION                   NCAA_CONFERENCE  FOURYEAR_ATHLETES  \
# 2                  2  Southwestern Athletic Conference                 43
# ...
